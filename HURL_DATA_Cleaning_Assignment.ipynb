# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path_excle=r"c:\Users\sachin tiwari\Downloads\Task1 (50).xls"
task_one_df=pd.read_excel(path_excle)
task_one_df.head()
# Out:
#                                                                               Note  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4  There are two icons one engineering icon and one Management Icon for this post
#
#   Advertisement  Number Advertisement date  \
# 0             E/02/2025         2025-04-15
# 1                   NaN                NaT
# 2                   NaN                NaT
# 3                   NaN                NaT
# 4                   NaN                NaT
#
#                                                        Post Name  Vacancy  \
# 0         Engineer (Ammonia/Urea/O&U/Electrical/Instrumentation)     33.0
# ...

# %%
# !pip install xlrd
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
path_2 = r"c:\Users\sachin tiwari\Downloads\data-export (1).csv"
task_two = pd.read_csv(path_2, 
                       sep=None, 
                       engine='python', 
                       on_bad_lines='skip', 
                       encoding='latin1')

task_two.head()
# Out:
#               # ----------------------------------------  \
# 0  Session primary channel group (Default channel group)
# 1                                                 Direct
# 2                                         Organic Social
# 3                                                 Direct
# 4                                         Organic Social
#
#                  Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0  Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                2024041623        237        300               144
# 2                2024041719        208        267               132
# 3                2024041723        188        233               115
# 4                2024041718        187        256               125
#
#                             Unnamed: 5                 Unnamed: 6  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# ...

# %%
# Cleaning the data
final_master_df['Salary'] = final_master_df['Salary'].astype(str)
def fix_salary(x):
    
    val = str(x).strip()
    
    
    if val != "nan" and val != "Not Available" and val != "" and "CTC" not in val:
        return val + " CTC"
    return val

# applying function
final_master_df['Salary'] = final_master_df['Salary'].apply(fix_salary)

# nan values change into Not Availible
final_master_df['Salary'] = final_master_df['Salary'].replace(['nan', 'nan CTC'], 'Not Available')


final_master_df.head()
# Out:
#                                                                              Note  \
# 0                                                                      No Remarks
# 1                                                                      No Remarks
# 2                                                                      No Remarks
# 3                                                                      No Remarks
# 4  There are two icons one engineering icon and one Management Icon for this post
#
#      Advt_No            Advt_Date  \
# 0  E/02/2025  2025-04-15 00:00:00
# 1        N/A        Not Available
# 2        N/A        Not Available
# 3        N/A        Not Available
# 4        N/A        Not Available
#
#                                                        Post Name Vacancy  \
# 0         Engineer (Ammonia/Urea/O&U/Electrical/Instrumentation)    33.0
# 1  Senior Engineer (Ammonia/Urea/O&U/Electrical/Instrumentation)    12.0
# ...

# %%
task_three.head()
# Out:
#             Name       Post      Mobile Organization
# 0           Annu    Manager  9876543210         HURL
# 1   Deepak Kumar   Engineer  8877665544         HURL
# 2  Sandeep Singh    Officer  7766554433         HURL

# %%
final_master_df.head()
# Out:
#                                                                              Note  \
# 0                                                                      No Remarks
# 1                                                                      No Remarks
# 2                                                                      No Remarks
# 3                                                                      No Remarks
# 4  There are two icons one engineering icon and one Management Icon for this post
#
#      Advt_No            Advt_Date  \
# 0  E/02/2025  2025-04-15 00:00:00
# 1        N/A        Not Available
# 2        N/A        Not Available
# 3        N/A        Not Available
# 4        N/A        Not Available
#
#                                                        Post Name Vacancy  \
# 0         Engineer (Ammonia/Urea/O&U/Electrical/Instrumentation)    33.0
# 1  Senior Engineer (Ammonia/Urea/O&U/Electrical/Instrumentation)    12.0
# ...

# %%
final_master_df=final_master_df.fillna("Not Available")
final_master_df.head()
# Out:
#                                                                              Note  \
# 0                                                                      No Remarks
# 1                                                                      No Remarks
# 2                                                                      No Remarks
# 3                                                                      No Remarks
# 4  There are two icons one engineering icon and one Management Icon for this post
#
#      Advt_No            Advt_Date  \
# 0  E/02/2025  2025-04-15 00:00:00
# 1        N/A        Not Available
# 2        N/A        Not Available
# 3        N/A        Not Available
# 4        N/A        Not Available
#
#                                                        Post Name Vacancy  \
# 0         Engineer (Ammonia/Urea/O&U/Electrical/Instrumentation)    33.0
# 1  Senior Engineer (Ammonia/Urea/O&U/Electrical/Instrumentation)    12.0
# ...

# %%
sns.set_theme(style="whitegrid")
plt.Figure(figsize=(14,7))

# %%
#Filtering not availiable which make graph clean
df_posts = final_master_df[final_master_df['Post'] != 'Not Available']

# 2. count of top 5 post
post_counts = df_posts['Post'].value_counts().head(5)

# 3. Plotting the pie chart
plt.figure(figsize=(10, 8))
plt.pie(post_counts, labels=post_counts.index, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'])

# 4. decoration
plt.title('Distribution of Top 5 Job Roles', fontsize=15, fontweight='bold')
plt.axis('equal')  # Taaki pie chart ekdum gol dikhe

plt.show()

# %%
#Post availablity
sns.set_theme(style="darkgrid")
plt.figure(figsize=(12,6))
ax=sns.countplot(y="Post",data=final_master_df,palette="rainbow",order=final_master_df["Post"].value_counts().index[:10])
plt.title("Top 10 job Profiles by frequency",fontsize=16,fontweight="bold")
plt.xlabel("Number of opening / Entries",fontsize=12,fontweight="bold")
plt.ylabel("Desgination",fontsize=12,fontweight="bold")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachin tiwari\AppData\Local\Temp\ipykernel_9568\1217155413.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(y="Post",data=final_master_df,palette="rainbow",order=final_master_df["Post"].value_counts().index[:10])
